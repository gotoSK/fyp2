# %%
import pandas as pd


data = pd.read_csv('2024-08-01_view.csv')

# %%
data
# Out:
#         id        contractId  contractType stockSymbol  buyerMemberId  \
# 0      NaN  2024080103057648           NaN        GFCL             21
# 1      NaN  2024080103057645           NaN        GFCL             37
# 2      NaN  2024080103057644           NaN        GFCL             32
# 3      NaN  2024080103057643           NaN        GFCL             55
# 4      NaN  2024080103057320           NaN        GFCL             32
# ...     ..               ...           ...         ...            ...
# 228920 NaN  2024080103000410           NaN       GMFBS             58
# 228921 NaN  2024080103000119           NaN       GMFBS             33
# 228922 NaN  2024080103000118           NaN       GMFBS             80
# 228923 NaN  2024080103000117           NaN       GMFBS             25
# 228924 NaN  2024080103000116           NaN       GMFBS             39
#
#         sellerMemberId  contractQuantity  contractRate  contractAmount  \
# ...

# %%
column_data = data["stockSymbol"]

# %%
print(column_data)
# Out:
# 0          GFCL
# 1          GFCL
# 2          GFCL
# 3          GFCL
# 4          GFCL
#           ...
# 228920    GMFBS
# 228921    GMFBS
# 228922    GMFBS
# 228923    GMFBS
# 228924    GMFBS
# Name: stockSymbol, Length: 228925, dtype: object
